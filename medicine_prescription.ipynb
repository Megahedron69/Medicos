# %% [markdown]
# <a href="https://colab.research.google.com/github/Megahedron69/Medicos/blob/beta/medicine_prescription.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hryt5eGK6k023hCNBi2w")
project = rf.workspace("final-research").project("prescriptionv7")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Prescriptionv7-1 in yolov11:: 100%|██████████| 525/525 [00:00<00:00, 9152.84it/s]

# %%
# !nvidia-smi
# Out:
# Sat Oct 19 09:51:22 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
Home = os.getcwd()
print(Home)
# Out:
# /content

# %%
# %pip install ultralytics supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.19 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hryt5eGK6k023hCNBi2w")
project = rf.workspace("testing-tbeeh").project("doctors-prescriptions-handwriting-ce8ll")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Doctors-prescriptions-handwriting-1 in yolov11:: 100%|██████████| 2412/2412 [00:00<00:00, 8408.07it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hryt5eGK6k023hCNBi2w")
project = rf.workspace("engineer-dlfou").project("doctor-prescription-ion3u-s1t0f")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Doctor-Prescription-1 in yolov11:: 100%|██████████| 2588/2588 [00:00<00:00, 3688.77it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hryt5eGK6k023hCNBi2w")
project = rf.workspace("final-research").project("prescription-v2")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Prescription-v2-1 in yolov11:: 100%|██████████| 92/92 [00:00<00:00, 6326.46it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hryt5eGK6k023hCNBi2w")
project = rf.workspace("bannari-amman-institute-of-technology-ifaw9").project("handwritten-recognition")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Handwritten-recognition-1 in yolov11:: 100%|██████████| 726/726 [00:00<00:00, 3088.07it/s]

# %%
# !yolo task=detect mode=train model=yolo11l.pt data=/content/Doctor-Prescription-1/data.yaml epochs=20 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.19 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train10/
# Out:
# args.yaml					     PR_curve.png	 train_batch1.jpg
# confusion_matrix_normalized.png			     R_curve.png	 train_batch2.jpg
# confusion_matrix.png				     results.csv	 val_batch0_labels.jpg
# events.out.tfevents.1729513828.80576542270a.20036.0  results.png	 val_batch0_pred.jpg
# F1_curve.png					     train_batch0.jpg	 val_batch1_labels.jpg
# labels_correlogram.jpg				     train_batch130.jpg  val_batch1_pred.jpg
# labels.jpg					     train_batch131.jpg  weights
# P_curve.png					     train_batch132.jpg

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'runs/detect/train9/confusion_matrix.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'runs/detect/train9/results.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'/content/runs/detect/train11/val_batch0_pred.jpg', width=1000)

# %%
# !yolo task=detect mode=val model=runs/detect/train11/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.18 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11l summary (fused): 464 layers, 25,325,572 parameters, 0 gradients, 86.8 GFLOPs
# val: Scanning /content/Doctors-prescriptions-handwriting-1/valid/labels.cache... 100 images, 2 backgrounds, 0 corrupt: 100% 100/100 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 817, len(boxes) = 950. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:03<00:00,  1.93it/s]
#                    all        100        950      0.744      0.658      0.725      0.506
#                      0         42         52      0.794       0.75      0.829      0.528
#                      1         14         14      0.745      0.643      0.726      0.315
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt conf=0.25 source=/content/press_1.jpg save=True
# Out:
# Ultralytics 8.3.18 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11l summary (fused): 464 layers, 25,283,938 parameters, 0 gradients, 86.6 GFLOPs
#
# image 1/1 /content/press_1.jpg: 128x640 1 Drug, 2 Frequencys, 83.5ms
# Speed: 1.2ms preprocess, 83.5ms inference, 545.2ms postprocess per image at shape (1, 3, 128, 640)
# Results saved to runs/detect/predict13
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('runs/detect/predict13'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[:3]:
  display(IPyImage(filename=img, width=600))
  print("\n")

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hryt5eGK6k023hCNBi2w")
project = rf.workspace("alternate-medicine-brand").project("alt-med-brand-v3")
version = project.version(1)
dataset = version.download("folder")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Alt-Med-Brand-v3-1 in folder:: 100%|██████████| 846/846 [00:00<00:00, 9902.86it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hryt5eGK6k023hCNBi2w")
project = rf.workspace("sakshi-deshpande-ddqcf").project("drug-names-2")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Drug-names-2-3 in yolov11:: 100%|██████████| 6052/6052 [00:00<00:00, 7398.80it/s]
